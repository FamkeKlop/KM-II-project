# %% [markdown]
# # Segment Anything in Medical Images ([colab](https://colab.research.google.com/drive/1N4wv9jljtEZ_w-f92iOLXCdkD-KJlsJH?usp=sharing))
# Segmentation is a fundamental task in medical imaging analysis. Deep learning-based models have shown great promise in medical image segmentation due to their ability to learn intricate image features and deliver accurate segmentation results across a diverse range of tasks. Recently, the Segmentation Anything Model (SAM) has shown remarkable versatility and performance in natural image segmentation. However, their application to medical image segmentation has been challenging due to the substantial domain gap. In this tutorial, we will introduce how to adapt the SAM's success to medical image segmentation.
#
# ## Overview
#
# 0. Installation
# 1. Methodology introduction
# 2. Load pre-trained model
# 3. Load data and run inference in an interactive way
# 4. Others
#    - a. Fine-tuning with customized datasets
#    - b. Medical image segmentation with text-based prompts
#    - c. Medical image segmentation with point-based prompts

# %% [markdown]
# ## Installation is super easy.
# On the local device:
# - Create a fresh environment `conda create -n medsam python=3.10 -y` and activate it `conda activate medsam`
# - Install [pytorch 2.0](https://pytorch.org/get-started/locally/)
# - Run the following command.
#
# If you are using Colab, you can directly run the following command.

# %%
# !pip install git+https://github.com/bowang-lab/MedSAM.git
# Out:
# Collecting git+https://github.com/bowang-lab/MedSAM.git
#   Cloning https://github.com/bowang-lab/MedSAM.git to c:\users\20203189\appdata\local\temp\pip-req-build-wx72o5so
#   Resolved https://github.com/bowang-lab/MedSAM.git to commit 7c5dfff6785a18aa8e5c1d2008e3edcf5bc0c4d0
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: monai in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from medsam==0.0.1) (1.4.0)
# Requirement already satisfied: matplotlib in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from medsam==0.0.1) (3.9.2)
# Requirement already satisfied: scikit-image in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from medsam==0.0.1) (0.24.0)
# Requirement already satisfied: SimpleITK>=2.2.1 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from medsam==0.0.1) (2.4.0)
# Requirement already satisfied: nibabel in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from medsam==0.0.1) (5.3.2)
# Requirement already satisfied: tqdm in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from medsam==0.0.1) (4.66.6)
# Requirement already satisfied: scipy in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from medsam==0.0.1) (1.14.1)
# Requirement already satisfied: ipympl in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from medsam==0.0.1) (0.9.4)
# Requirement already satisfied: opencv-python in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from medsam==0.0.1) (4.10.0.84)
# Requirement already satisfied: jupyterlab in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from medsam==0.0.1) (4.3.0)
# Requirement already satisfied: ipywidgets in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from medsam==0.0.1) (8.1.5)
# Requirement already satisfied: ipython-genutils in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from ipympl->medsam==0.0.1) (0.2.0)
# Requirement already satisfied: ipython<9 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipympl->medsam==0.0.1) (8.23.0)
# Requirement already satisfied: numpy in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from ipympl->medsam==0.0.1) (1.26.4)
# Requirement already satisfied: pillow in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from ipympl->medsam==0.0.1) (11.0.0)
# Requirement already satisfied: traitlets<6 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipympl->medsam==0.0.1) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipywidgets->medsam==0.0.1) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from ipywidgets->medsam==0.0.1) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from ipywidgets->medsam==0.0.1) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from matplotlib->medsam==0.0.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from matplotlib->medsam==0.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from matplotlib->medsam==0.0.1) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from matplotlib->medsam==0.0.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from matplotlib->medsam==0.0.1) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from matplotlib->medsam==0.0.1) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from matplotlib->medsam==0.0.1) (2.9.0.post0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyterlab->medsam==0.0.1) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyterlab->medsam==0.0.1) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from jupyterlab->medsam==0.0.1) (6.29.4)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyterlab->medsam==0.0.1) (3.1.4)
# Requirement already satisfied: jupyter-core in c:\users\20203189\appdata\roaming\python\python310\site-packages (from jupyterlab->medsam==0.0.1) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyterlab->medsam==0.0.1) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyterlab->medsam==0.0.1) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyterlab->medsam==0.0.1) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyterlab->medsam==0.0.1) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyterlab->medsam==0.0.1) (75.1.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyterlab->medsam==0.0.1) (2.0.2)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from jupyterlab->medsam==0.0.1) (6.4)
# Requirement already satisfied: torch>=1.9 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from monai->medsam==0.0.1) (2.5.1)
# Requirement already satisfied: importlib-resources>=5.12 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from nibabel->medsam==0.0.1) (6.4.5)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from nibabel->medsam==0.0.1) (4.11.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from scikit-image->medsam==0.0.1) (3.4.2)
# Requirement already satisfied: imageio>=2.33 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from scikit-image->medsam==0.0.1) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from scikit-image->medsam==0.0.1) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from scikit-image->medsam==0.0.1) (0.4)
# Requirement already satisfied: colorama in c:\users\20203189\appdata\roaming\python\python310\site-packages (from tqdm->medsam==0.0.1) (0.4.6)
# Requirement already satisfied: anyio in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from httpx>=0.25.0->jupyterlab->medsam==0.0.1) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from httpx>=0.25.0->jupyterlab->medsam==0.0.1) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from httpx>=0.25.0->jupyterlab->medsam==0.0.1) (1.0.6)
# Requirement already satisfied: idna in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from httpx>=0.25.0->jupyterlab->medsam==0.0.1) (3.10)
# Requirement already satisfied: sniffio in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from httpx>=0.25.0->jupyterlab->medsam==0.0.1) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->medsam==0.0.1) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab->medsam==0.0.1) (1.8.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab->medsam==0.0.1) (8.6.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab->medsam==0.0.1) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab->medsam==0.0.1) (1.6.0)
# Requirement already satisfied: psutil in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab->medsam==0.0.1) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab->medsam==0.0.1) (26.0.2)
# Requirement already satisfied: decorator in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl->medsam==0.0.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl->medsam==0.0.1) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl->medsam==0.0.1) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl->medsam==0.0.1) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl->medsam==0.0.1) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\20203189\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl->medsam==0.0.1) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jinja2>=3.0.3->jupyterlab->medsam==0.0.1) (3.0.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from jupyter-core->jupyterlab->medsam==0.0.1) (4.2.1)
# Requirement already satisfied: pywin32>=300 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from jupyter-core->jupyterlab->medsam==0.0.1) (306)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (2.0.14)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->medsam==0.0.1) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->medsam==0.0.1) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->medsam==0.0.1) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->medsam==0.0.1) (2.32.3)
# Requirement already satisfied: six>=1.5 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib->medsam==0.0.1) (1.16.0)
# Requirement already satisfied: filelock in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from torch>=1.9->monai->medsam==0.0.1) (3.16.1)
# Requirement already satisfied: fsspec in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from torch>=1.9->monai->medsam==0.0.1) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from torch>=1.9->monai->medsam==0.0.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from sympy==1.13.1->torch>=1.9->monai->medsam==0.0.1) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython<9->ipympl->medsam==0.0.1) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->medsam==0.0.1) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->medsam==0.0.1) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->medsam==0.0.1) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->medsam==0.0.1) (0.20.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (2.20.0)
# Requirement already satisfied: wcwidth in c:\users\20203189\appdata\roaming\python\python310\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl->medsam==0.0.1) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->medsam==0.0.1) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->medsam==0.0.1) (2.2.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from stack-data->ipython<9->ipympl->medsam==0.0.1) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\20203189\appdata\roaming\python\python310\site-packages (from stack-data->ipython<9->ipympl->medsam==0.0.1) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\20203189\appdata\roaming\python\python310\site-packages (from stack-data->ipython<9->ipympl->medsam==0.0.1) (0.2.2)
# Requirement already satisfied: webencodings in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (2.6)
# Requirement already satisfied: pycparser in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\20203189\.conda\envs\medsam\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->medsam==0.0.1) (2.9.0.20241003)
#   Running command git clone --filter=blob:none --quiet https://github.com/bowang-lab/MedSAM.git 'C:\Users\20203189\AppData\Local\Temp\pip-req-build-wx72o5so'

# %% [markdown]
# ## 1. Methodology introduction
#
# SAM is a promptable segmentation model and it supports three types of prompts: bounding box, point, and text. (Note: The text-prompt function in SAM is not publicly available.) While the concept of fully automatic medical image segmentation foundation models is enticing, it is fraught with challenges that make it impractical. One of the primary challenges is the variability inherent in segmentation tasks. For example, given a liver cancer CT image, the segmentation task can vary depending on the specific clinical scenario. One clinician might be interested in segmenting the liver tumor, while another might need to segment the entire liver and surrounding organs. Additionally, the variability in imaging modalities presents another challenge. Modalities such as CT and MR generate 3D images, whereas others like X-Ray and ultrasound yield 2D images. These variabilities in task definition and imaging modalities complicate the design of a fully automatic model capable of accurately anticipating and addressing the diverse requirements of different users.
#
# Considering these challenges, we argue that a more practical approach is to develop a promptable 2D model for general medical image segmentation. The model can be easily adapted to specific tasks based on user-provided prompts, offering enhanced flexibility and adaptability. It is also able to handle both 2D and 3D images by processing 3D images as a series of 2D slices. Compared to point-based and text-based prompts, the bounding box-based prompt has three main advantages: 1) it has less ambiguity and can clearly specify the ROI with minor user intervention (clicking on the top left and bottom right points); 2) it doesn't require multiple trial and error; 3) it can be seamlessly integrated into tumor measurements (e.g., Response Evaluation Criteria In Solid Tumors [RECIST](https://radiologyassistant.nl/more/recist-1-1/recist-1-1)) by simulating bounding box from the linear annotation (e.g., long axis and short axis).
#
#
# In order to use the pre-trained weights, we follow SAM's network architecture in SAM, including an image encoder, a prompt encoder, and a mask decoder. The image encoder maps the input image into a high-dimensional image embedding space. The prompt encoder transforms the user-drawn bounding boxes into feature representations via positional encoding. Finally, the mask decoder fuses the image embedding and prompt features using cross-attention. It should be noted that the image embedding only needs to be computed once during inference. Then, one can draw different bounding boxes to segment different targets in real-time.
#
# ![network](assets/architecture.png)

# %% [markdown]
# ## 2. Load pre-trained model
#
# Please download the checkpoint [here](https://drive.google.com/drive/folders/1ETWmi4AiniJeWOt6HAsYgTjYv_fkgzoN?usp=drive_link). This pre-trained model can be directed loaded with SAM's checkpoint loader.

# %%
# %matplotlib widget
import torch
from segment_anything import sam_model_registry
import sys
sys.path.append('functions/')
from utils.demo import BboxPromptDemo
MedSAM_CKPT_PATH = "work_dir/MedSAM/medsam_vit_b.pth"
# device = "cuda:0"
device = torch.device('cpu')        #Changed it to CPU to work on our laptops
medsam_model = sam_model_registry['vit_b'](checkpoint=MedSAM_CKPT_PATH)
medsam_model = medsam_model.to(device)
medsam_model.eval()
# Out:
# c:\Users\20203189\.conda\envs\medsam\lib\site-packages\segment_anything\build_sam.py:144: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(f, map_location=torch.device('cpu'))
# Sam(
#   (image_encoder): ImageEncoderViT(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#     )
#     (blocks): ModuleList(
#       (0-11): 12 x Block(
#         (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=768, out_features=2304, bias=True)
#           (proj): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           (act): GELU(approximate='none')
#         )
#       )
#     )
#     (neck): Sequential(
#       (0): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): LayerNorm2d()
#       (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (3): LayerNorm2d()
#     )
#   )
#   (prompt_encoder): PromptEncoder(
#     (pe_layer): PositionEmbeddingRandom()
#     (point_embeddings): ModuleList(
#       (0-3): 4 x Embedding(1, 256)
#     )
#     (not_a_point_embed): Embedding(1, 256)
#     (mask_downscaling): Sequential(
#       (0): Conv2d(1, 4, kernel_size=(2, 2), stride=(2, 2))
#       (1): LayerNorm2d()
#       (2): GELU(approximate='none')
#       (3): Conv2d(4, 16, kernel_size=(2, 2), stride=(2, 2))
#       (4): LayerNorm2d()
#       (5): GELU(approximate='none')
#       (6): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (no_mask_embed): Embedding(1, 256)
#   )
#   (mask_decoder): MaskDecoder(
#     (transformer): TwoWayTransformer(
#       (layers): ModuleList(
#         (0-1): 2 x TwoWayAttentionBlock(
#           (self_attn): Attention(
#             (q_proj): Linear(in_features=256, out_features=256, bias=True)
#             (k_proj): Linear(in_features=256, out_features=256, bias=True)
#             (v_proj): Linear(in_features=256, out_features=256, bias=True)
#             (out_proj): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (cross_attn_token_to_image): Attention(
#             (q_proj): Linear(in_features=256, out_features=128, bias=True)
#             (k_proj): Linear(in_features=256, out_features=128, bias=True)
#             (v_proj): Linear(in_features=256, out_features=128, bias=True)
#             (out_proj): Linear(in_features=128, out_features=256, bias=True)
#           )
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (lin1): Linear(in_features=256, out_features=2048, bias=True)
#             (lin2): Linear(in_features=2048, out_features=256, bias=True)
#             (act): ReLU()
#           )
#           (norm3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm4): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (cross_attn_image_to_token): Attention(
#             (q_proj): Linear(in_features=256, out_features=128, bias=True)
#             (k_proj): Linear(in_features=256, out_features=128, bias=True)
#             (v_proj): Linear(in_features=256, out_features=128, bias=True)
#             (out_proj): Linear(in_features=128, out_features=256, bias=True)
#           )
#         )
#       )
#       (final_attn_token_to_image): Attention(
#         (q_proj): Linear(in_features=256, out_features=128, bias=True)
#         (k_proj): Linear(in_features=256, out_features=128, bias=True)
#         (v_proj): Linear(in_features=256, out_features=128, bias=True)
#         (out_proj): Linear(in_features=128, out_features=256, bias=True)
#       )
#       (norm_final_attn): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (iou_token): Embedding(1, 256)
#     (mask_tokens): Embedding(4, 256)
#     (output_upscaling): Sequential(
#       (0): ConvTranspose2d(256, 64, kernel_size=(2, 2), stride=(2, 2))
#       (1): LayerNorm2d()
#       (2): GELU(approximate='none')
#       (3): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#       (4): GELU(approximate='none')
#     )
#     (output_hypernetworks_mlps): ModuleList(
#       (0-3): 4 x MLP(
#         (layers): ModuleList(
#           (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#           (2): Linear(in_features=256, out_features=32, bias=True)
#         )
#       )
#     )
#     (iou_prediction_head): MLP(
#       (layers): ModuleList(
#         (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#         (2): Linear(in_features=256, out_features=4, bias=True)
#       )
#     )
#   )
# )

# %% [markdown]
# ## 3. Load data and run inference in an interactive way
#
# One can directly draw the bounding box to segment the targets. Here are two examples of the abdomen CT image and colon gland pathology image.
# Please use relatively tight bounding boxes since the model was not trained with large bounding box perturbations.
#
# ![abdomen CT](assets/seg_demo.gif)

# %%
#Load data
import numpy as np
import nrrd
import matplotlib.pyplot as plt
import sys
sys.path.append('functions/')
from visualizations import *

# path_data = 'C:/Users/20202932/8FM30_Klinischemodule1/KM-II-project-1/data/'
image000_path = 'data/Dataset002_Version1_FullMouse\imagesTr\Mouse_labelled_000_0000.nii.gz'
path_data = 'data/'
# Read the NRRD file
# readdata, header = nrrd.read(path_data + 'Baseline 15-05-2020 (0) - Mouse 5 - Separate Segmentations Muscle (1)/Baseline 15-05-2020 (0) - Mouse 5 - Separate Segmentations Muscle/50kVp_0000.dcm.nrrd')
readdata, header = nrrd.read(path_data + '50kVp_0000.dcm.nrrd')
readdata = load_data(image000_path)

slice_index = 100
image = readdata[: ,: , slice_index]

# Convert grayscale image to RGB image for the SAM model
if len(image.shape) == 2:
    image = np.stack([image]*3, axis=-1)

# Scale the pixel values to [0, 1]
# First calculate the min and max value of image
old_min, old_max = image.min(), image.max()

# Then scale
image = (image - old_min) / (old_max - old_min)

# Clip the values to ensure they are between 0 and 1
slice_rgb = np.clip(image, 0, 1)

bbox_prompt_demo = BboxPromptDemo(medsam_model)
bbox_prompt_demo.show(slice_rgb)
# Out:
# Button(description='clear', style=ButtonStyle())
# Canvas(footer_visible=False, header_visible=False, resizable=False, toolbar=Toolbar(toolitems=[('Home', 'Reset…
# Button(description='save', style=ButtonStyle())
# Segmentation result saved to c:\Users\20203189\Documents\Biomedische Technologie\Year 5\KM II\Project\KM-II-project

# %%
# colon gland pathology image
# important: please re-run this cell to avoid using the above image embedding.
img = "assets/pathology.png"
bbox_prompt_demo = BboxPromptDemo(medsam_model)
bbox_prompt_demo.show(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 5
#       3 img = "assets/pathology.png"
#       4 bbox_prompt_demo = BboxPromptDemo(medsam_model)
# ----> 5 bbox_prompt_demo.show(img)
#
# File c:\Users\20203189\Documents\Biomedische Technologie\Year 5\KM II\Project\KM-II-project\functions\utils\demo.py:141, in BboxPromptDemo.show(self, image, fig_size, random_color, alpha)
#     137 def show(self, image, fig_size=5, random_color=True, alpha=0.65):
#     138     # Check if image is a string (file path) or a NumPy array
#     139     if isinstance(image, str):
#     140         # Use set_image_path only for file paths
# --> 141         self.set_image_path(image)
#     142     elif isinstance(image, np.ndarray):
#     143         # Directly set the image if it's a NumPy array
#     144         self._set_image(image)
#
# File c:\Users\20203189\Documents\Biomedische Technologie\Year 5\KM II\Project\KM-II-project\functions\utils\demo.py:152, in BboxPromptDemo.set_image_path(self, image_path)
#     150 def set_image_path(self, image_path):
#     151     image = cv2.imread(image_path)
# --> 152     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#     153     self._set_image(image)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# ## 4. Others
#
# Now, we have shown how to use MedSAM to segment medical images by drawing bounding boxes. We also provide advanced tutorials to show
#    - a. How was MedSAM trained? or How to fine-tune SAM on customized datasets? [training](https://github.com/bowang-lab/MedSAM/tree/main#model-training)
#    - b. How to fine-tune the model with text-based prompts: [training](https://github.com/bowang-lab/MedSAM/tree/main/extensions/text_prompt) and [inference colab](https://colab.research.google.com/drive/1wexPLewVMI-9EMiplfyoEtGGayYDH3tt?usp=sharing)
#    - c. How to fine-tune the model with point-based prompts: [training](https://github.com/bowang-lab/MedSAM/tree/main/extensions/point_prompt) and [inference colab](https://colab.research.google.com/drive/1cCBw_IhdPiWE4sN7QwqKJPgAFlWsKgkm?usp=sharing)
